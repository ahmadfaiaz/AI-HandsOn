# %% [markdown]
# ## Part Four
#
# ### Modules

# %%
import my_module
# Out:
# my_module

# %%
my_module.add(1,2)
# Out:
# 3

# %% [markdown]
# ### Best practice of importing module

# %%
# from my_module import add
import my_module

add = my_module.add

add(1,2)
# Out:
# 3

# %% [markdown]
# ##### Each module has it own private namespace which used as global namespace by all func defined in the module. additionally Special char in directory name is not allowed for Eg: import direcory_name1.my_module

# %% [markdown]
# ### importlib library use to reload lib

# %%
import importlib
import my_module

importlib.reload(my_module)

my_module.add(1, 2)
# Out:
# hey I am out side the main module lol
# 3

# %%
import sys

print(sys.builtin_module_names)
# Out:
# ('_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_imp', '_interpchannels', '_interpqueues', '_interpreters', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha2', '_sha3', '_signal', '_sre', '_stat', '_statistics', '_string', '_struct', '_suggestions', '_symtable', '_sysconfig', '_thread', '_tokenize', '_tracemalloc', '_typing', '_warnings', '_weakref', '_winapi', 'array', 'atexit', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'sys', 'time', 'winreg', 'xxsubtype', 'zlib')

# %% [markdown]
# #### PYTHONPATH Fact:
#
# export PYTHONPATH="/current-dir:python_default_dir will give priority to your local module if the name is equal to any python built in module

# %% [markdown]
# ### Modify path using sys (Standard Library)

# %%
# with sys path you can modify path you don't need miss around PYTHONPATH in shell
# fun fact on standard library - its not override like other built-in library (Eg: random that can be override)

import sys

for path in sys.path:
    print(path)

# sys.path.append("C:\Users\ahmad.faiaz.bakshi\OneDrive - Accenture\Documents\Github\AI-HandsOn\Python-tutorial")
# Out:
# c:\Users\ahmad.faiaz.bakshi\AppData\Local\Programs\Python\Python313\python313.zip
# c:\Users\ahmad.faiaz.bakshi\AppData\Local\Programs\Python\Python313\DLLs
# c:\Users\ahmad.faiaz.bakshi\AppData\Local\Programs\Python\Python313\Lib
# c:\Users\ahmad.faiaz.bakshi\AppData\Local\Programs\Python\Python313
#
# C:\Users\ahmad.faiaz.bakshi\AppData\Roaming\Python\Python313\site-packages
# c:\Users\ahmad.faiaz.bakshi\AppData\Local\Programs\Python\Python313\Lib\site-packages

# %%
print(dir())
print(locals())
print(globals())

# for k, v in list(locals().items()):
#     print(f"{k} : {v}")
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'open', 'path', 'quit', 'sys']
# ...

# %% [markdown]
# ##### If you are using from ..module import name and your file also contain "__ name __ = __ main __" and the module is in up level dir then it won't work unless you use absolute path
